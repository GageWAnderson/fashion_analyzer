# %%
import os
import re
import json
import io
import requests
import ast
from typing import Optional
from datetime import date
from collections import deque


from dotenv import load_dotenv

from pydantic import BaseModel, Field
from bs4 import BeautifulSoup
from playwright.async_api import async_playwright
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.messages import AIMessage
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_text_splitters import RecursiveCharacterTextSplitter
from unstructured.partition.html import partition_html
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
# TODO: Implement a web page parser like this
# "Write a playwright script to click on all the product links on the web page and goto those URLs"

# %%
load_dotenv()
# Out:
# True

# %%
# TODO: Consider an HTML-aware text splitter to not cut off HTML tags
SEARCH_MAX_RESULTS = 2
MAX_SEARCH_DEPTH = 2
CHUNK_SIZE = 20000
MIN_CHUNK_SIZE = 1000
CHUNK_OVERLAP = 100
MAX_RETRIES = 3
MAX_N_LINKS_TO_SEARCH = 3
SEARCH_QUERY = "Ring Jacket coats"

# %%
# TODO: Consider fine tuning a smaller model on GPT-4o's output to train it to
# Parse clothing web pages consistently!!!
# That fine tuning would be the kicker feature to show that I really understand ML/AI engineering!!!
llm = ChatOpenAI(
    model="gpt-4o",
    api_key=os.getenv("OPENAI_API_KEY"),
    temperature=0.0,
    streaming=False,
)

fast_llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=os.getenv("OPENAI_API_KEY"),
    temperature=0.0,
    streaming=False,
)

# %%
class SimpleClothingItem(BaseModel):
    name: str = Field(..., description="Descriptive name of the clothing item")
    price: Optional[float] = Field(None, description="Current price of the item")
    image_url: Optional[str] = Field(None, description="URL of the item's image")
    link: Optional[str] = Field(None, description="URL of the item's page")


class ClothingItemList(BaseModel):
    clothing_items: list[SimpleClothingItem]

# %%
html_contains_clothing_info_prompt = """
Given the following HTML snippet:
{html}

Does this HTML contain information about a clothing item or links that are promising for finding clothing items?
Return "true" if it does, "false" otherwise.
"""

# %%
playwright_click_promt = """
Given the following HTML content, write a playwright script to click on all the product links.
Keep a list[str] of all the URLs that you click on in a result list and return it.

HTML CONTENT:
{html_content}

Use the async playwright python API to write your code.
Return the function to extract in a function called `parse_clothing_sections`.
Put all your python code in a code block in markdown format i.e ```code ...```
Return only the python code, nothing else.

The function should look like this:
```python
async def parse_clothing_sections(html: str) -> list[str]:
    ...
```

Parsing Script Python:
"""

# %%
generate_scraping_script_prompt = """
Given the following HTML:
{html}

Write a parser using BeautifulSoup that pulls out all sections involving clothing.
Return the function to extract in a function called `parse_clothing_sections`.
Put all your python code in a code block in markdown format i.e ```code ...```
Return only the python code, nothing else.

The function should look like this:
```python
async def parse_clothing_sections(html: str):
    ...
```

Parsing Script Python:
"""

# %%
is_clothing_product_link_prompt = """
Given the following URL:
{url}

Is this a URL for a clothing product?
Return "true" if it is, "false" otherwise.
"""

# %%
def get_test_html() -> str:
    with open("test_web_page.html", "r") as f:
        return f.read()

# %%
def split_html(html: str) -> list[str]:
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=CHUNK_SIZE,
        # min_chunk_size=MIN_CHUNK_SIZE,
        chunk_overlap=CHUNK_OVERLAP,
        length_function=len,
        is_separator_regex=False,
    )
    return text_splitter.split_text(html)

# %%
def extract_code_from_markdown(markdown: str) -> str:
    # Try to extract code blocks marked with ```python first
    if "```python" in markdown:
        return markdown.split("```python")[1].split("```")[0]
    # If no python blocks found, try generic code blocks
    elif "```" in markdown:
        return markdown.split("```")[1].split("```")[0]
    return ""

# %%
class SearchResult(BaseModel):
    url: str = Field(..., description="URL of the search result")
    html_content: Optional[str] = Field(
        None, description="HTML content of the search result"
    )
    depth: int = Field(0, description="Depth of the search result in the BFS search")


def get_search_results_from_url(url: str, depth: int = 0) -> list[SearchResult]:
    res = []
    response = requests.get(url)
    response.raise_for_status()
    html_content = response.text
    for split_html_content in split_html(html_content):
        res.append(SearchResult(url=url, html_content=split_html_content, depth=depth))
    return res


def get_search_results(search_query: str) -> list[SearchResult]:
    tavily_search = TavilySearchResults(
        max_results=SEARCH_MAX_RESULTS, include_raw_content=True
    )
    search_results = tavily_search.invoke({"query": search_query})
    res = []
    for search_result in search_results:
        print(f"Search result: {search_result}")
        url = search_result["url"]
        try:
            res.extend(get_search_results_from_url(url, 0))
        except Exception as e:
            print(f"Error fetching HTML from {url}: {e}")
            continue
    return res

# %%
def get_parsing_script(search_results: dict) -> str:
    prompt = PromptTemplate(
        input_variables=["html_content"],
        template=playwright_click_promt,
    )
    extract_prompt = prompt.format(html_content=search_results["content"])
    # print(f"Extract prompt: {extract_prompt}")
    raw_res = AIMessage.model_validate(llm.invoke(extract_prompt)).content
    # print(f"Raw res: {raw_res}")
    return extract_code_from_markdown(raw_res)

# %%
def validate_parsing_script(script: str) -> bool:
    """
    Validate the generated parsing script for security concerns.
    Returns True if script passes security checks, False otherwise.
    """
    # List of forbidden operations/keywords that could be dangerous
    forbidden = [
        "import os",
        "import sys",
        "subprocess",
        "eval(",
        "exec(",
        "__import__",
        "open(",
        "write",
        "delete",
        "remove",
    ]

    # Check for forbidden operations
    for item in forbidden:
        if item in script.lower():
            print(f"Security violation: Found forbidden operation '{item}'")
            return False

    # Only allow importing safe parsing libraries
    allowed_imports = {
        "json",
        "asyncio",
        "playwright",
        "beautifulsoup4",
        "bs4",
        "lxml",
        "html.parser",
        "re",
    }

    import_lines = [
        line.strip()
        for line in script.split("\n")
        if line.strip().startswith("import") or line.strip().startswith("from")
    ]

    for line in import_lines:
        module = line.split()[1].split(".")[0]
        if module not in allowed_imports:
            print(f"Security violation: Unauthorized import '{module}'")
            return False

    return True

# %%
class FunctionExtractor(ast.NodeVisitor):
    def __init__(self):
        self.functions = []

    def visit_FunctionDef(self, node):
        # Collect regular function name and body
        self.functions.append({
            'name': node.name,
            'type': 'regular',
            'body': ast.unparse(node)
        })
        self.generic_visit(node)

    def visit_AsyncFunctionDef(self, node):
        # Collect async function name and body
        self.functions.append({
            'name': node.name,
            'type': 'async',
            'body': ast.unparse(node)
        })
        self.generic_visit(node)

def extract_functions_from_code(code):
    tree = ast.parse(code)
    extractor = FunctionExtractor()
    extractor.visit(tree)
    return extractor.functions

# %%
async def execute_parsing_script(script: str, html: str) -> list:
    local_namespace = {}
    try:
        # Execute the function body in the local namespace
        exec(script, globals(), local_namespace)
        parse_clothing_sections = local_namespace.get("parse_clothing_sections")
        if not parse_clothing_sections:
            raise ValueError("parse_clothing_sections function not found")
        return await parse_clothing_sections(html)
    except Exception as e:
        print(f"Error executing parsing script: {str(e)}")

# %%
def result_extractor(raw_results: str) -> ClothingItemList:
    structured_output_llm = llm.with_structured_output(ClothingItemList)
    
    for attempt in range(MAX_RETRIES):
        try:
            raw_res = structured_output_llm.invoke(raw_results)
            print(f"Raw res: {raw_res}")
            return ClothingItemList.model_validate(raw_res)
        except Exception as e:
            if attempt == MAX_RETRIES - 1:  # Last attempt
                raise
            print(f"Attempt {attempt + 1} failed: {str(e)}. Retrying...")

# %%
async def parse_search_result(raw_html: str) -> list[SimpleClothingItem]:
    try:
        return result_extractor(raw_html).clothing_items
    except Exception as e:
        print(f"Error parsing results: {str(e)}")
        return []
    # try:
    #     parsing_script = get_parsing_script({"content": raw_html})
    # except Exception as e:
    #     print(f"Error getting parsing script: {str(e)}")
    #     raise e
    # if validate_parsing_script(parsing_script):
    #     # print(f"Raw Parsing script: {parsing_script}")
    #     extracted_funcs = extract_functions_from_code(parsing_script)
    #     # print(f"Extracted functions: {extracted_funcs}")
    #     if len(extracted_funcs) != 1:
    #         print(f"Expected 1 function, got {len(extracted_funcs)}")
    #         raise e

    #     parse_clothing_sections_func = extracted_funcs[0]["body"]
    #     # print(f"Parsing script:\n{parse_clothing_sections_func}")
    #     results_safe = validate_parsing_script(parse_clothing_sections_func)
    #     if not results_safe:
    #         print("Parse clothing sections function failed security validation")
    #         raise e
    #     print(f"Executing parsing script: {parse_clothing_sections_func}")
    #     raw_results = await execute_parsing_script(
    #         parse_clothing_sections_func, raw_html
    #     )
    #     if raw_results and len(raw_results) > 0:
    #         try:
    #             parsed_results = result_extractor(str(raw_results))
    #             print(f"Parsed results: {parsed_results}")
    #             return parsed_results.clothing_items
    #         except Exception as e:
    #             print(f"Error parsing results: {str(e)}")
    #             raise e
    #     else:
    #         return []
    # else:
    #     print("Generated script failed security validation")
    #     return []

# %%
def contains_clothing_item_info_or_links(html_chunk: str) -> bool:
    """
    Returns True if the HTML chunk is about a clothing item
    or links that are promising for finding clothing items, False otherwise.
    """
    prompt = PromptTemplate(
        input_variables=["html"],
        template=html_contains_clothing_info_prompt,
    )
    extract_prompt = prompt.format(html=html_chunk)
    raw_res = AIMessage.model_validate(fast_llm.invoke(extract_prompt)).content
    return "true" in raw_res.lower()  # TODO: Consider structured output in the future

# %%
async def click_links_and_get_results(parent_url: str, raw_html: str) -> list[str]:
    """
    Extracts all links from the raw HTML string.

    Args:
        raw_html: Raw HTML string to parse

    Returns:
        List of URLs found in the HTML
    """
    links = []
    try:
        # Parse HTML and get all links
        soup = BeautifulSoup(raw_html, "html.parser")
        anchors = soup.find_all("a")

        for anchor in anchors:
            try:
                # Get the href attribute
                href = anchor.get("href")

                if href and not href.startswith("#"):  # Skip anchor links
                    if not href.lower().startswith(("http://", "https://")):
                        # Relative URL - join with parent URL
                        href = urljoin(parent_url, href)
                    links.append(href)

            except Exception as e:
                print(f"Error processing link: {str(e)}")
                continue

    except Exception as e:
        print(f"Error parsing HTML: {str(e)}")

    return links

# %%
def is_clothing_product_link(url: str) -> bool:
    prompt = PromptTemplate(
        input_variables=["url"],
        template=is_clothing_product_link_prompt,
    )
    extract_prompt = prompt.format(url=url)
    raw_res = AIMessage.model_validate(fast_llm.invoke(extract_prompt)).content
    return "true" in raw_res.lower()

# %%
# HACK: This code exploits a common pattern in web pages where clothing items are 1 click away from the main page
# Therefore, no BFS is required, we just search 1 level down in the graph and filter for the nodes that involve clothing

# %%
# full_html = get_test_html()
# TODO: Consider implementing the link clicking with normal playwright code
search_results = get_search_results(SEARCH_QUERY)
final_res = []
for search_result in search_results:
    for chunk in split_html(search_result.html_content):
        clicked_links = await click_links_and_get_results(search_result.url, chunk)
        # print(f"Clicked Links: {clicked_links}")
        for clicked_link in clicked_links:
            if is_clothing_product_link(clicked_link):
                print(f"Found clothing product link: {clicked_link}")
                try:
                    raw_html_content = requests.get(clicked_link).text
                    for split_html_content in split_html(raw_html_content):
                        if not contains_clothing_item_info_or_links(split_html_content):
                            print("Skipping chunk")
                            continue
                        result = await parse_search_result(split_html_content)
                        print(f"Parsed results: {result}")
                        final_res.extend(result)
                except Exception as e:
                    print(f"Error parsing chunk: {str(e)}")
                    continue

print(f"final res: {final_res}")
# Out:
# Search result: {'url': 'https://www.supplyandadvise.com/collections/ring-jacket', 'content': "RING JACKET | Supply & Advise FREE SHIPPING ON ORDERS OVER $250 FREE SHIPPING ON ORDERS OVER $250 CREATE AN ACCOUNT Account Brands ▾ Brands ENGINEERED GARMENTS LEVI'S VINTAGE CLOTHING RANDOLPH ENGINEERING RING JACKET TANNER GOODS Categories ▾ Shoe Care & Accessories Suits & Jackets RING JACKET Established in 1954, Ring Jacket is regarded as one of the finest ready-to-wear producers of suiting and tailored clothing in the world. Ring Jacket works with the finest mills in the world like VBC, Loro Piana & also with smaller local mills to produce proprietary fabrics that have become iconic. RING JACKET Shipping Brands ENGINEERED GARMENTS LEVI'S VINTAGE CLOTHING RANDOLPH ENGINEERING RING JACKET TANNER GOODS Shoe Care & Accessories Suits & Jackets Account"}
# Search result: {'url': 'https://www.therealreal.com/designers/ring-jacket', 'content': "Shop authentic Ring Jacket at up to 90% off. The RealReal is the world's #1 luxury consignment online store. All items are authenticated through a rigorous process overseen by experts. ... Trench Coat. Size: XXL - Price was: $225.00 - Now 20% off - $180.00 is the current price. Ring Jacket. Wool Blazer. Size: L - Price was: $375.00"}
# Error fetching HTML from https://www.therealreal.com/designers/ring-jacket: 403 Client Error: Forbidden for url: https://www.therealreal.com/designers/ring-jacket
# Found clothing product link: https://www.supplyandadvise.com/collections/alden
# Skipping chunk
# Skipping chunk
Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-XwvJU0oTph8nySwcbLMSRZ3R on tokens per min (TPM): Limit 10000, Used 6610, Requested 4976. Please try again in 9.516s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}. Retrying...
# Attempt 2 failed: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-XwvJU0oTph8nySwcbLMSRZ3R on tokens per min (TPM): Limit 10000, Used 6594, Requested 4976. Please try again in 9.42s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}. Retrying...
# Error parsing results: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-XwvJU0oTph8nySwcbLMSRZ3R on tokens per min (TPM): Limit 10000, Used 6602, Requested 4976. Please try again in 9.468s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Parsed results: []
# Attempt 1 failed: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-XwvJU0oTph8nySwcbLMSRZ3R on tokens per min (TPM): Limit 10000, Used 6606, Requested 5012. Please try again in 9.708s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}. Retrying...
# Raw res: clothing_items=[SimpleClothingItem(name='MOCCASIN COLOR 8 SHELL CORDOVAN 563 - 8.5', price=None, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 8', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 8.5', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 9', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 9.5', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 10', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 10.5', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 11', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 11.5', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 12', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER TAN SUEDE 29332F - 8', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER TAN SUEDE 29332F - 8.5', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER TAN SUEDE 29332F - 9', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER TAN SUEDE 29332F - 9.5', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER TAN SUEDE 29332F - 10', price=60300.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER TAN SUEDE 29332F - 10.5', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER TAN SUEDE 29332F - 11', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER TAN SUEDE 29332F - 11.5', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER TAN SUEDE 29332F - 12', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER SNUFF SUEDE 29336F - 8', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER SNUFF SUEDE 29336F - 8.5', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER SNUFF SUEDE 29336F - 9', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER SNUFF SUEDE 29336F - 9.5', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER SNUFF SUEDE 29336F - 10', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER SNUFF SUEDE 29336F - 10.5', price=60300.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER SNUFF SUEDE 29336F - 11', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER SNUFF SUEDE 29336F - 11.5', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER SNUFF SUEDE 29336F - 12', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER SNUFF SUEDE 29336F - 7.5', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER SNUFF SUEDE 29336F - 7', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER NAVY SUEDE 29331F - 8', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER NAVY SUEDE 29331F - 8.5', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER NAVY SUEDE 29331F - 9', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER NAVY SUEDE 29331F - 9.5', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER NAVY SUEDE 29331F - 10', price=36180.0, image_url=None, link=None), SimpleClothingItem(name='UNLINED DOVER NAVY SUEDE 29331F - 10.5', price=36180.0, image_url=None, link=None), SimpleClothingItem(name= ...
# Parsed results: [SimpleClothingItem(name='MOCCASIN COLOR 8 SHELL CORDOVAN 563 - 8.5', price=None, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 8', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 8.5', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 9', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 9.5', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 10', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 10.5', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TASSEL MOCCASIN BLACK SHELL CORDOVAN 664 - 11', price=71640.0, image_url=None, link=None), SimpleClothingItem(name='TAS
# Raw res: clothing_items=[SimpleClothingItem(name='LONGWING BLUCHER NAVY SUEDE 97676F - 10.5', price=34260.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER NAVY SUEDE 97676F - 11', price=34260.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER NAVY SUEDE 97676F - 11.5', price=34260.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER NAVY SUEDE 97676F - 12', price=34260.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 6.5', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 7', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 7.5', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 8', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 8.5', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 9', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 9.5', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 10', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 10.5', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 11', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 11.5', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 12', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 7.5', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 8', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 8.5', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 9', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 9.5', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 10', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 10.5', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 11', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 11.5', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 12', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 6', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 7', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 8', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 8.5', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 9', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 9.5', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 10', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 10.5', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 11', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 1 ...
# Parsed results: [SimpleClothingItem(name='LONGWING BLUCHER NAVY SUEDE 97676F - 10.5', price=34260.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER NAVY SUEDE 97676F - 11', price=34260.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER NAVY SUEDE 97676F - 11.5', price=34260.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER NAVY SUEDE 97676F - 12', price=34260.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 6.5', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 7', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 7.5', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 8', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 8.5', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 9', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 9.5', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 10', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 10.5', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 11', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 11.5', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='LONGWING BLUCHER COLOR 8 SHELL CORDOVAN 975 - 12', price=84000.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 7.5', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 8', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 8.5', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 9', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 9.5', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 10', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 10.5', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 11', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 11.5', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='CHUKKA COLOR 8 SHELL CORDOVAN D5708 - 12', price=83800.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 6', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 7', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 8', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 8.5', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 9', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 9.5', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 10', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 10.5', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 11', price=60700.0, image_url=None, link=None), SimpleClothingItem(name='INDY BOOT CLASSIC BROWN 405 - 11.5', pr ...
# Skipping chunk
# Raw res: clothing_items=[SimpleClothingItem(name='Alden Indy Boot in Brown Chromexcel', price=579.0, image_url='https://cdn.shopify.com/s/files/1/0420/0029/products/alden-indy-boot-brown-chromexcel.jpg?v=1616161616', link='https://www.supplyandadvise.com/products/alden-indy-boot-brown-chromexcel'), SimpleClothingItem(name='Alden Plain Toe Blucher in Black Shell Cordovan', price=795.0, image_url='https://cdn.shopify.com/s/files/1/0420/0029/products/alden-plain-toe-blucher-black-shell-cordovan.jpg?v=1616161616', link='https://www.supplyandadvise.com/products/alden-plain-toe-blucher-black-shell-cordovan'), SimpleClothingItem(name='Alden Tassel Moccasin in Burgundy', price=650.0, image_url='https://cdn.shopify.com/s/files/1/0420/0029/products/alden-tassel-moccasin-burgundy.jpg?v=1616161616', link='https://www.supplyandadvise.com/products/alden-tassel-moccasin-burgundy')]
# Parsed results: [SimpleClothingItem(name='Alden Indy Boot in Brown Chromexcel', price=579.0, image_url='https://cdn.shopify.com/s/files/1/0420/0029/products/alden-indy-boot-brown-chromexcel.jpg?v=1616161616', link='https://www.supplyandadvise.com/products/alden-indy-boot-brown-chromexcel'), SimpleClothingItem(name='Alden Plain Toe Blucher in Black Shell Cordovan', price=795.0, image_url='https://cdn.shopify.com/s/files/1/0420/0029/products/alden-plain-toe-blucher-black-shell-cordovan.jpg?v=1616161616', link='https://www.supplyandadvise.com/products/alden-plain-toe-blucher-black-shell-cordovan'), SimpleClothingItem(name='Alden Tassel Moccasin in Burgundy', price=650.0, image_url='https://cdn.shopify.com/s/files/1/0420/0029/products/alden-tassel-moccasin-burgundy.jpg?v=1616161616', link='https://www.supplyandadvise.com/products/alden-tassel-moccasin-burgundy')]
# Skipping chunk
# Raw res: clothing_items=[SimpleClothingItem(name='Alden Shoe', price=550.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/alden_shoe.jpg', link='https://www.supplyandadvise.com/products/alden-shoe'), SimpleClothingItem(name='Alden Boot', price=650.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/alden_boot.jpg', link='https://www.supplyandadvise.com/products/alden-boot'), SimpleClothingItem(name='Alden Loafer', price=500.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/alden_loafer.jpg', link='https://www.supplyandadvise.com/products/alden-loafer')]
# Parsed results: [SimpleClothingItem(name='Alden Shoe', price=550.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/alden_shoe.jpg', link='https://www.supplyandadvise.com/products/alden-shoe'), SimpleClothingItem(name='Alden Boot', price=650.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/alden_boot.jpg', link='https://www.supplyandadvise.com/products/alden-boot'), SimpleClothingItem(name='Alden Loafer', price=500.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/alden_loafer.jpg', link='https://www.supplyandadvise.com/products/alden-loafer')]
# Raw res: clothing_items=[SimpleClothingItem(name='100 HANDS', price=None, image_url=None, link='/collections/100-hands'), SimpleClothingItem(name='8.15 AUGUST FIFTEENTH', price=None, image_url=None, link='/collections/8-15-august-fifteenth'), SimpleClothingItem(name='ALDEN', price=None, image_url=None, link='/collections/alden'), SimpleClothingItem(name="ANDERSON'S", price=None, image_url=None, link='/collections/andersons'), SimpleClothingItem(name='BAXTER OF CALIFORNIA', price=None, image_url=None, link='/collections/baxter-of-california'), SimpleClothingItem(name="CARAN D'ACHE", price=None, image_url=None, link='/collections/caran-dache'), SimpleClothingItem(name='CHAMULA', price=None, image_url=None, link='/collections/chamula'), SimpleClothingItem(name='CIRE TRUDON', price=None, image_url=None, link='/collections/cire-trudon'), SimpleClothingItem(name='CODIS MAYA', price=None, image_url=None, link='/collections/codis-maya'), SimpleClothingItem(name='COOL GREASE', price=None, image_url=None, link='/collections/cool-grease'), SimpleClothingItem(name='DS & DURGA', price=None, image_url=None, link='/collections/ds-and-durga'), SimpleClothingItem(name="DRAKE'S", price=None, image_url=None, link='/collections/drakes'), SimpleClothingItem(name='EBBETS FIELD FLANNELS', price=None, image_url=None, link='/collections/ebbets-field-flannels'), SimpleClothingItem(name='ENGINEERED GARMENTS', price=None, image_url=None, link='/collections/engineered-garments'), SimpleClothingItem(name='FELLOW', price=None, image_url=None, link='/collections/fellow'), SimpleClothingItem(name='FILSON', price=None, image_url=None, link='/collections/filson'), SimpleClothingItem(name='GANT RUGGER', price=None, image_url=None, link='/collections/gant-rugger'), SimpleClothingItem(name='GITMAN VINTAGE', price=None, image_url=None, link='/collections/gitman-vintage'), SimpleClothingItem(name='HAMILTON', price=None, image_url=None, link='/collections/hamilton'), SimpleClothingItem(name='HOMESPUN KNITWEAR', price=None, image_url=None, link='/collections/homespun-knitwear'), SimpleClothingItem(name='JOHN SMEDLEY', price=None, image_url=None, link='/collections/john-smedley'), SimpleClothingItem(name='KLETTERWERKS', price=None, image_url=None, link='/collections/kletterwerks'), SimpleClothingItem(name='LADY WHITE CO.', price=None, image_url=None, link='/collections/lady-white-co'), SimpleClothingItem(name="LEVI'S VINTAGE CLOTHING", price=None, image_url=None, link='/collections/levis-vintage-clothing'), SimpleClothingItem(name='MAKR', price=None, image_url=None, link='/collections/makr'), SimpleClothingItem(name='MARVIS', price=None, image_url=None, link='/collections/marvis'), SimpleClothingItem(name='MCMC', price=None, image_url=None, link='/collections/mcmc'), SimpleClothingItem(name='NATIONAL ATHLETIC GOODS', price=None, image_url=None, link='/collections/national-athletic-goods'), SimpleClothingItem(name='NORTH SEA CLOTHING', price=None, image_url=None, link='/collections/north-sea-clothing'), SimpleClothingItem(name='oRSLOW', price=None, image_url=None, link='/collections/orslow'), SimpleClothingItem(name='PANTHERELLA', price=None, image_url=None, link='/collections/pantherella'), SimpleClothingItem(name='PAPA NUI', price=None, image_url=None, link='/collections/papa-nui'), SimpleClothingItem(name='POSTALCO', price=None, image_url=None, link='/collections/postalco'), SimpleClothingItem(name='PRORASO', price=None, image_url=None, link='/collections/proraso'), SimpleClothingItem(name='RANDOLPH ENGINEERING', price=None, image_url=None, link='/collections/randolph-engineering'), SimpleClothingItem(name='RIN STUDIOS', price=None, image_url=None, link='/collections/rin-tanaka'), SimpleClothingItem(name='RING JACKET', price=None, image_url=None, link='/collections/ring-jacket'), SimpleClothingItem(name='RoToTo', price=None, image_url=None, link='/collections/rototo'), SimpleClothingItem(name='RRL', price=None, image_url=None, link='/collections/rrl'), SimpleClothing ...
# Parsed results: [SimpleClothingItem(name='100 HANDS', price=None, image_url=None, link='/collections/100-hands'), SimpleClothingItem(name='8.15 AUGUST FIFTEENTH', price=None, image_url=None, link='/collections/8-15-august-fifteenth'), SimpleClothingItem(name='ALDEN', price=None, image_url=None, link='/collections/alden'), SimpleClothingItem(name="ANDERSON'S", price=None, image_url=None, link='/collections/andersons'), SimpleClothingItem(name='BAXTER OF CALIFORNIA', price=None, image_url=None, link='/collections/baxter-of-california'), SimpleClothingItem(name="CARAN D'ACHE", price=None, image_url=None, link='/collections/caran-dache'), SimpleClothingItem(name='CHAMULA', price=None, image_url=None, link='/collections/chamula'), SimpleClothingItem(name='CIRE TRUDON', price=None, image_url=None, link='/collections/cire-trudon'), SimpleClothingItem(name='CODIS MAYA', price=None, image_url=None, link='/collections/codis-maya'), SimpleClothingItem(name='COOL GREASE', price=None, image_url=None, link='/collections/cool-grease'), SimpleClothingItem(name='DS & DURGA', price=None, image_url=None, link='/collections/ds-and-durga'), SimpleClothingItem(name="DRAKE'S", price=None, image_url=None, link='/collections/drakes'), SimpleClothingItem(name='EBBETS FIELD FLANNELS', price=None, image_url=None, link='/collections/ebbets-field-flannels'), SimpleClothingItem(name='ENGINEERED GARMENTS', price=None, image_url=None, link='/collections/engineered-garments'), SimpleClothingItem(name='FELLOW', price=None, image_url=None, link='/collections/fellow'), SimpleClothingItem(name='FILSON', price=None, image_url=None, link='/collections/filson'), SimpleClothingItem(name='GANT RUGGER', price=None, image_url=None, link='/collections/gant-rugger'), SimpleClothingItem(name='GITMAN VINTAGE', price=None, image_url=None, link='/collections/gitman-vintage'), SimpleClothingItem(name='HAMILTON', price=None, image_url=None, link='/collections/hamilton'), SimpleClothingItem(name='HOMESPUN KNITWEAR', price=None, image_url=None, link='/collections/homespun-knitwear'), SimpleClothingItem(name='JOHN SMEDLEY', price=None, image_url=None, link='/collections/john-smedley'), SimpleClothingItem(name='KLETTERWERKS', price=None, image_url=None, link='/collections/kletterwerks'), SimpleClothingItem(name='LADY WHITE CO.', price=None, image_url=None, link='/collections/lady-white-co'), SimpleClothingItem(name="LEVI'S VINTAGE CLOTHING", price=None, image_url=None, link='/collections/levis-vintage-clothing'), SimpleClothingItem(name='MAKR', price=None, image_url=None, link='/collections/makr'), SimpleClothingItem(name='MARVIS', price=None, image_url=None, link='/collections/marvis'), SimpleClothingItem(name='MCMC', price=None, image_url=None, link='/collections/mcmc'), SimpleClothingItem(name='NATIONAL ATHLETIC GOODS', price=None, image_url=None, link='/collections/national-athletic-goods'), SimpleClothingItem(name='NORTH SEA CLOTHING', price=None, image_url=None, link='/collections/north-sea-clothing'), SimpleClothingItem(name='oRSLOW', price=None, image_url=None, link='/collections/orslow'), SimpleClothingItem(name='PANTHERELLA', price=None, image_url=None, link='/collections/pantherella'), SimpleClothingItem(name='PAPA NUI', price=None, image_url=None, link='/collections/papa-nui'), SimpleClothingItem(name='POSTALCO', price=None, image_url=None, link='/collections/postalco'), SimpleClothingItem(name='PRORASO', price=None, image_url=None, link='/collections/proraso'), SimpleClothingItem(name='RANDOLPH ENGINEERING', price=None, image_url=None, link='/collections/randolph-engineering'), SimpleClothingItem(name='RIN STUDIOS', price=None, image_url=None, link='/collections/rin-tanaka'), SimpleClothingItem(name='RING JACKET', price=None, image_url=None, link='/collections/ring-jacket'), SimpleClothingItem(name='RoToTo', price=None, image_url=None, link='/collections/rototo'), SimpleClothingItem(name='RRL', price=None, image_url=None, link='/collections/rrl'), SimpleClothingItem(nam ...
# Skipping chunk
# Skipping chunk
# Found clothing product link: https://www.supplyandadvise.com/collections/chamula
# Raw res: clothing_items=[SimpleClothingItem(name='Chamula Braided Horsehair Bracelet', price=45.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/chamula_braided_horsehair_bracelet.jpg', link='https://www.supplyandadvise.com/products/chamula-braided-horsehair-bracelet'), SimpleClothingItem(name='Chamula Wool Knit Cap', price=60.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/chamula_wool_knit_cap.jpg', link='https://www.supplyandadvise.com/products/chamula-wool-knit-cap'), SimpleClothingItem(name='Chamula Handwoven Scarf', price=120.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/chamula_handwoven_scarf.jpg', link='https://www.supplyandadvise.com/products/chamula-handwoven-scarf')]
# Parsed results: [SimpleClothingItem(name='Chamula Braided Horsehair Bracelet', price=45.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/chamula_braided_horsehair_bracelet.jpg', link='https://www.supplyandadvise.com/products/chamula-braided-horsehair-bracelet'), SimpleClothingItem(name='Chamula Wool Knit Cap', price=60.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/chamula_wool_knit_cap.jpg', link='https://www.supplyandadvise.com/products/chamula-wool-knit-cap'), SimpleClothingItem(name='Chamula Handwoven Scarf', price=120.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/chamula_handwoven_scarf.jpg', link='https://www.supplyandadvise.com/products/chamula-handwoven-scarf')]
# Skipping chunk
# Attempt 1 failed: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-XwvJU0oTph8nySwcbLMSRZ3R on requests per min (RPM): Limit 3, Used 3, Requested 1. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}. Retrying...
# Raw res: clothing_items=[SimpleClothingItem(name='BENDABLE HORSE HAIR BRACELET BLACK/BLUE/WHITE', price=32.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/CHAMULA-BENDABLE-BLACK-BLUE-1.jpg?v=1523163940', link='https://www.supplyandadvise.com/products/chamula-bentable-h-h-h-bracelet-blk-blue'), SimpleClothingItem(name='BENDABLE HORSE HAIR BRACELET BLUE/BLACK/WHITE', price=32.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/CHAMULA-BENDABLE-BLUE-BLACK-1.jpg?v=1659071239', link='https://www.supplyandadvise.com/products/chamula-bentable-h-h-h-bracelet-blu-blk'), SimpleClothingItem(name='BENDABLE HORSE HAIR BRACELET TAN/RED/WHITE', price=64.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/CHAMULA-BENDABLE-TAN-RED-1.jpg?v=1676005624', link='https://www.supplyandadvise.com/products/chamula-bentable-h-h-h-bracelet-tan-red'), SimpleClothingItem(name='BENDABLE HORSE HAIR BRACELET WHITE/RED/BLUE', price=32.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/CHAMULA-BENDABLE-WHITE-RED-BLUE-1.jpg?v=1659071238', link='https://www.supplyand
vise.com/products/chamula-indian-concho-bracelet-bl-wht'), SimpleClothingItem(name='CONCHO BRACELET BROWN/WHITE', price=40.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/CHAMULA-CONCHO-BROWN-WHITE-1.jpg?v=1639372044', link='https://www.supplyandadvise.com/products/chamula-indian-concho-bracelet-br-wht'), SimpleClothingItem(name='CONCHO BRACELET WHITE/BLACK/BLUE', price=20.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/CHAMULA-CONCHO-WHITE-BLUE-1.jpg?v=1639804060', link='https://www.supplyandadvise.com/products/chamula-indian-concho-bracelet-wht-blue'), SimpleClothingItem(name='CONCHO BRACELET WHITE/BLACK/RED', price=20.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/CHAMULA-CONCHO-WHITE-RED-1.jpg?v=1639026486', link='https://www.supplyandadvise.com/products/chamula-indian-concho-bracelet-wht-rd'), SimpleClothingItem(name='HORSE HAIR BRAIDED BRACELET WHITE/TURQUOISE/RED', price=23.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/CHAMULA-HORSE-HAIR-BRAIDED-BRACELET-WHITE-TURQUOISE-RED.jpg?v=1677733614', link='https://www.supplyandadvise.com/products/chamula-h-h-braided-bracelet-red-turq-wht')]
# Raw res: clothing_items=[SimpleClothingItem(name='Chamula Collection Item 1', price=120.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/chamula_item1.jpg', link='https://www.supplyandadvise.com/products/chamula-item-1'), SimpleClothingItem(name='Chamula Collection Item 2', price=150.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/chamula_item2.jpg', link='https://www.supplyandadvise.com/products/chamula-item-2'), SimpleClothingItem(name='Chamula Collection Item 3', price=180.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/chamula_item3.jpg', link='https://www.supplyandadvise.com/products/chamula-item-3')]
# Parsed results: [SimpleClothingItem(name='Chamula Collection Item 1', price=120.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/chamula_item1.jpg', link='https://www.supplyandadvise.com/products/chamula-item-1'), SimpleClothingItem(name='Chamula Collection Item 2', price=150.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/chamula_item2.jpg', link='https://www.supplyandadvise.com/products/chamula-item-2'), SimpleClothingItem(name='Chamula Collection Item 3', price=180.0, image_url='https://www.supplyandadvise.com/cdn/shop/products/chamula_item3.jpg', link='https://www.supplyandadvise.com/products/chamula-item-3')]
# Raw res: clothing_items=[SimpleClothingItem(name='BENDABLE HORSE HAIR BRACELET BLACK/BLUE/WHITE', price=32.0, image_url='//www.supplyandadvise.com/cdn/shop/products/CHAMULA-BENDABLE-BLACK-BLUE-1_large.jpg?v=1523163940', link='/products/chamula-bentable-h-h-h-bracelet-blk-blue')]
# Parsed results: [SimpleClothingItem(name='BENDABLE HORSE HAIR BRACELET BLACK/BLUE/WHITE', price=32.0, image_url='//www.supplyandadvise.com/cdn/shop/products/CHAMULA-BENDABLE-BLACK-BLUE-1_large.jpg?v=1523163940', link='/products/chamula-bentable-h-h-h-bracelet-blk-blue')]
